# %% [markdown]
# # ag2gcal - Texas A&M Planting Calendar to gCal
#
# Convert the calendars at `calendar_source_urls` to Google Calendar event entries at `calendar_destination_ids`.
#
# Example:
#
# ![](img/ag2gcal.png)

# %%
import datetime
from datetime import timedelta
import os

import pandas as pd
import dateparser
import gcsa
import gcsa.recurrence

from gcsa.event import Event
from gcsa.google_calendar import GoogleCalendar

# %% [markdown]
# ### Various variables
#
# - `region_columns` - list of all regions contained in the tables
# - `all_columns` - includes the leftmost index for the veggie
# - `gcloud_creds_path` - OAuth credentials with permissions to access the person's calendars
# - `calendar_source_urls` - source sites for the planting schedules
# - `calendar_destination_ids` - map of region to gCal calendar ID where we'll eventually write the calendar events

# %%
region_columns = ['Region I', 'Region II', 'Region III', 'Region IV', 'Region V']
all_columns = ['Vegetable'] + region_columns

# %%
gcloud_creds_path = os.environ['GOOGLE_CLOUD_AG2GCAL_CREDS_PATH']

# %%
calendar_source_urls = {
    'Spring': 'https://aggie-horticulture.tamu.edu/archives/parsons/earthkind/ekgarden14.html',
    'Fall': 'https://aggie-horticulture.tamu.edu/archives/parsons/fallgarden/falldirect.html'
}

# %%
calendar_destination_ids = {
    'Region III': 'c_00rno1r8kjpj2tcse3vdkourl8@group.calendar.google.com'
}

# %% [markdown]
# ### Parse date ranges from tables
#
# The dates in the tables are somewhat inconsistent. Play around with them a bit to get them into a useable, two entry array of `[start_date, end_date]`.

# %%
def try_parse_date_range(val, year=datetime.datetime.now().year, default_window_in_days=14, date_format='%b %d %Y'):
    stringified_val = str(val)
    
    start_date = None
    end_date = None
    
    if '-' in stringified_val:
        raw_date_range = val.split('-')
        
        if len(raw_date_range) == 2:
            raw_date_range[:] = [f'{raw_date} {year}' for raw_date in raw_date_range]
            
            start_date = raw_date_range[0]
            end_date = raw_date_range[1]
    elif stringified_val.startswith('After'):
        start_date = f'{stringified_val.replace("After", "")} {year}'
    else:
        start_date = f'{stringified_val} {year}'
        
    if start_date != "nat" and isinstance(start_date, str):
        start_date = dateparser.parse(start_date)
        
        if end_date != None:
            end_date = dateparser.parse(end_date)
        
        if start_date != None and end_date == None:
            end_date = start_date + timedelta(days=default_window_in_days)
    
    return [start_date, end_date]

# %% [markdown]
# ### Parse the HTML tables and coerce them in to DataFrames

# %%
def parse_url(season, url):
    print(url)
    
    raw_tables = pd.read_html(url)
    
    calendar_table = raw_tables[1]
    
    if calendar_table.iloc[0][0] == 'Vegetables':
        calendar_table.drop([0], inplace=True)

    calendar_table.columns = all_columns
    calendar_table['season'] = season
        
    return calendar_table

# %% [markdown]
# ### Do it

# %%
raw_calendars = pd.DataFrame()

for calendar_source in calendar_source_urls.items():
    calendar = parse_url(*calendar_source)
    raw_calendars = raw_calendars.append(calendar)
    
raw_calendars.reset_index(inplace=True)
# Out:
# https://aggie-horticulture.tamu.edu/archives/parsons/earthkind/ekgarden14.html
# Asparagus
# https://aggie-horticulture.tamu.edu/archives/parsons/fallgarden/falldirect.html
# Vegetables

# %%
for region_column in region_columns:
    raw_calendars[region_column] = raw_calendars[region_column].apply(try_parse_date_range)

# %%
unpivoted_calendar = raw_calendars.melt(id_vars=['Vegetable', 'season'], value_vars=region_columns, var_name='region', value_name='date_range')

# %%
unpivoted_calendar['start_date'] = unpivoted_calendar.apply(lambda row: row['date_range'][0], axis=1)
unpivoted_calendar['end_date'] = unpivoted_calendar.apply(lambda row: row['date_range'][1], axis=1)
unpivoted_calendar.drop(['date_range'], axis=1, inplace=True)

# %% [markdown]
# ### Establish gcal clients
#
# This uses a desktop OAuth flow, so each calendar will kick out a URL to authorize. You'll need to replace the `&amp;` in the URL with actual ampersands.
#
# TODO: figure out how to output and not urlencode within a given cell.

# %%
calendar_clients = {}

for region, calendar_id in calendar_destination_ids.items():
    calendar_clients[region] = GoogleCalendar(calendar_id, credentials_path=gcloud_creds_path)

# %% [markdown]
# ### Write events to calendars
#
# Iterate over each of the regions and write the events for that region to the respective calendar defined in `calendar_source_urls`

# %%
for region in region_columns:
    print(f'Adding events for {region}')
    
    if region in calendar_clients:
        calendar_client = calendar_clients[region]
    
        for index, row in unpivoted_calendar[unpivoted_calendar['region'] == region].iterrows():
            if row['start_date'] != None and not pd.isnull(row['start_date']):
                event = Event(
                    row['Vegetable'],
                    start=row['start_date'],
                    end=row['end_date']
                )

                calendar_client.add_event(event)
# Out:
# Region I
# Region II
# Region III
# 130 --> Vegetable               Asparagus
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-02-15 00:00:00
# Name: 130, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 131 --> Vegetable        Beans, snap bush
# season                     spring
# region                 Region III
# start_date    2020-03-05 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 131, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 132 --> Vegetable        Beans, snap pole
# season                     spring
# region                 Region III
# start_date    2020-03-05 00:00:00
# end_date      2020-04-15 00:00:00
# Name: 132, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 133 --> Vegetable        Beans, Lima bush
# season                     spring
# region                 Region III
# start_date    2020-03-15 00:00:00
# end_date      2020-04-15 00:00:00
# Name: 133, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 134 --> Vegetable        Beans, Lima pole
# season                     spring
# region                 Region III
# start_date    2020-03-15 00:00:00
# end_date      2020-04-15 00:00:00
# Name: 134, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 135 --> Vegetable                   Beets
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 135, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 136 --> Vegetable                Broccoli
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 136, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 137 --> Vegetable     Brussels sprouts
# season                  spring
# region              Region III
# start_date                 NaT
# end_date                   NaT
# Name: 137, dtype: object --> <class 'pandas._libs.tslibs.nattype.NaTType'>
# 138 --> Vegetable                 Cabbage
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 138, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 139 --> Vegetable                 Carrots
# season                     spring
# region                 Region III
# start_date    2020-01-15 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 139, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 140 --> Vegetable     Cauliflower (transplant)
# season                          spring
# region                      Region III
# start_date         2020-02-01 00:00:00
# end_date           2020-03-01 00:00:00
# Name: 140, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 141 --> Vegetable            Chard, Swiss
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-10 00:00:00
# Name: 141, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 142 --> Vegetable     Collards Mar 1-May 1Feb 15-Apr 10Feb 1-Mar 25J...
# season                                                   spring
# region                                               Region III
# start_date                                  2020-08-10 00:00:00
# end_date                                    2020-08-24 00:00:00
# Name: 142, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 143 --> Vegetable             Corn, sweet
# season                     spring
# region                 Region III
# start_date    2020-02-25 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 143, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 144 --> Vegetable                Cucumber
# season                     spring
# region                 Region III
# start_date    2020-03-05 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 144, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 145 --> Vegetable                Eggplant
# season                     spring
# region                 Region III
# start_date    2020-03-15 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 145, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 146 --> Vegetable     Garlic (cloves)
# season                 spring
# region             Region III
# start_date                NaT
# end_date                  NaT
# Name: 146, dtype: object --> <class 'pandas._libs.tslibs.nattype.NaTType'>
# 147 --> Vegetable                Kohlrabi
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 147, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 148 --> Vegetable                 Lettuce
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-15 00:00:00
# Name: 148, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 149 --> Vegetable     Muskmelon (cantaloupe)
# season                        spring
# region                    Region III
# start_date       2020-03-15 00:00:00
# end_date         2020-05-01 00:00:00
# Name: 149, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 150 --> Vegetable                 Mustard
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-04-01 00:00:00
# Name: 150, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 151 --> Vegetable          Onion (plants)
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 151, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 152 --> Vegetable                 Parsley
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 152, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 153 --> Vegetable           Peas, English
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 153, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 154 --> Vegetable          Peas, Southern
# season                     spring
# region                 Region III
# start_date    2020-03-25 00:00:00
# end_date      2020-05-20 00:00:00
# Name: 154, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 155 --> Vegetable     Pepper (transplant)
# season                     spring
# region                 Region III
# start_date    2020-03-15 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 155, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 156 --> Vegetable                  Potato
# season                     spring
# region                 Region III
# start_date    2020-02-15 00:00:00
# end_date      2020-03-01 00:00:00
# Name: 156, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 157 --> Vegetable     Potato, sweet (slips)
# season                       spring
# region                   Region III
# start_date      2020-04-10 00:00:00
# end_date        2020-05-15 00:00:00
# Name: 157, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 158 --> Vegetable                 Pumpkin
# season                     spring
# region                 Region III
# start_date    2020-04-01 00:00:00
# end_date      2020-04-20 00:00:00
# Name: 158, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 159 --> Vegetable                  Radish
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 159, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 160 --> Vegetable                 Spinach
# season                     spring
# region                 Region III
# start_date    2020-01-01 00:00:00
# end_date      2020-02-15 00:00:00
# Name: 160, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 161 --> Vegetable          Squash, summer
# season                     spring
# region                 Region III
# start_date    2020-03-05 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 161, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 162 --> Vegetable          Squash, winter
# season                     spring
# region                 Region III
# start_date    2020-03-05 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 162, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 163 --> Vegetable     Tomato (transplant)
# season                     spring
# region                 Region III
# start_date    2020-03-15 00:00:00
# end_date      2020-04-10 00:00:00
# Name: 163, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 164 --> Vegetable                  Turnip
# season                     spring
# region                 Region III
# start_date    2020-02-01 00:00:00
# end_date      2020-03-10 00:00:00
# Name: 164, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 165 --> Vegetable              Watermelon
# season                     spring
# region                 Region III
# start_date    2020-03-15 00:00:00
# end_date      2020-05-01 00:00:00
# Name: 165, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 166 --> Vegetable        Beans, snap bush
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 166, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 167 --> Vegetable        Beans, Lima bush
# season                       fall
# region                 Region III
# start_date    2020-08-20 00:00:00
# end_date      2020-09-03 00:00:00
# Name: 167, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 168 --> Vegetable                   Beets
# season                       fall
# region                 Region III
# start_date    2020-10-15 00:00:00
# end_date      2020-10-29 00:00:00
# Name: 168, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 169 --> Vegetable                Broccoli
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 169, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 170 --> Vegetable        Brussels sprouts
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 170, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 171 --> Vegetable                 Cabbage
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 171, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 172 --> Vegetable                 Carrots
# season                       fall
# region                 Region III
# start_date    2020-11-10 00:00:00
# end_date      2020-11-24 00:00:00
# Name: 172, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 173 --> Vegetable             Cauliflower
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 173, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 174 --> Vegetable            Chard, Swiss
# season                       fall
# region                 Region III
# start_date    2020-10-01 00:00:00
# end_date      2020-10-15 00:00:00
# Name: 174, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 175 --> Vegetable                Collards
# season                       fall
# region                 Region III
# start_date    2020-10-10 00:00:00
# end_date      2020-10-24 00:00:00
# Name: 175, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 176 --> Vegetable             Corn, sweet
# season                       fall
# region                 Region III
# start_date    2020-08-20 00:00:00
# end_date      2020-09-03 00:00:00
# Name: 176, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 177 --> Vegetable                Cucumber
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 177, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 178 --> Vegetable                Eggplant
# season                       fall
# region                 Region III
# start_date    2020-07-01 00:00:00
# end_date      2020-07-15 00:00:00
# Name: 178, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 179 --> Vegetable         Garlic (cloves)
# season                       fall
# region                 Region III
# start_date    2020-10-10 00:00:00
# end_date      2020-10-24 00:00:00
# Name: 179, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 180 --> Vegetable                Kohlrabi
# season                       fall
# region                 Region III
# start_date    2020-09-10 00:00:00
# end_date      2020-09-24 00:00:00
# Name: 180, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 181 --> Vegetable           Lettuce, leaf
# season                       fall
# region                 Region III
# start_date    2020-10-10 00:00:00
# end_date      2020-10-24 00:00:00
# Name: 181, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 182 --> Vegetable                 Mustard
# season                       fall
# region                 Region III
# start_date    2020-11-01 00:00:00
# end_date      2020-11-15 00:00:00
# Name: 182, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 183 --> Vegetable            Onion (seed)
# season                       fall
# region                 Region III
# start_date    2020-11-01 00:00:00
# end_date      2020-11-15 00:00:00
# Name: 183, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 184 --> Vegetable                 Parsley
# season                       fall
# region                 Region III
# start_date    2020-10-10 00:00:00
# end_date      2020-10-24 00:00:00
# Name: 184, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 185 --> Vegetable          Peas, southern
# season                       fall
# region                 Region III
# start_date    2020-08-01 00:00:00
# end_date      2020-08-15 00:00:00
# Name: 185, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 186 --> Vegetable                  Pepper
# season                       fall
# region                 Region III
# start_date    2020-07-01 00:00:00
# end_date      2020-07-15 00:00:00
# Name: 186, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 187 --> Vegetable                  Potato
# season                       fall
# region                 Region III
# start_date    2020-09-01 00:00:00
# end_date      2020-09-15 00:00:00
# Name: 187, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 188 --> Vegetable                 Pumpkin
# season                       fall
# region                 Region III
# start_date    2020-08-01 00:00:00
# end_date      2020-08-15 00:00:00
# Name: 188, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 189 --> Vegetable                  Radish
# season                       fall
# region                 Region III
# start_date    2020-11-25 00:00:00
# end_date      2020-12-09 00:00:00
# Name: 189, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 190 --> Vegetable                 Spinach
# season                       fall
# region                 Region III
# start_date    2020-11-15 00:00:00
# end_date      2020-11-29 00:00:00
# Name: 190, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 191 --> Vegetable          Squash, summer
# season                       fall
# region                 Region III
# start_date    2020-09-10 00:00:00
# end_date      2020-09-24 00:00:00
# Name: 191, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 192 --> Vegetable          Squash, winter
# season                       fall
# region                 Region III
# start_date    2020-08-10 00:00:00
# end_date      2020-08-24 00:00:00
# Name: 192, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 193 --> Vegetable                  Tomato
# season                       fall
# region                 Region III
# start_date    2020-07-01 00:00:00
# end_date      2020-07-15 00:00:00
# Name: 193, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 194 --> Vegetable                  Turnip
# season                       fall
# region                 Region III
# start_date    2020-11-01 00:00:00
# end_date      2020-11-15 00:00:00
# Name: 194, dtype: object --> <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# Region IV
# Region V
